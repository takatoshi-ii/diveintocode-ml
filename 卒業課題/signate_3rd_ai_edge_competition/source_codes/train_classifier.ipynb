# %%
import tensorflow as tf
import numpy as np
import efficientnet.keras as efn 
from efficientnet.keras import preprocess_input

from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras.optimizers import Adadelta
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, Callback
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
batch_size_all    = 5
epochs_all        = 100
#imgs_train        = 375787
#imgs_val          = 19832
imgs_train        = 762253
imgs_val          = 40497
path_train        = r'D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/'
path_val          = r'D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\val/'

# %%
#https://github.com/yu4u/cutout-random-erasing
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=True):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        if np.random.rand() > p: return input_img
        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)
            if left + w <= img_w and top + h <= img_h: break
        if np.random.rand() >0.5: c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else: c = np.random.uniform(v_l, v_h)
        input_img[top:top + h, left:left + w, :] = c
        return input_img
    return eraser


gen_t = ImageDataGenerator(
    horizontal_flip=True,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    preprocessing_function=get_random_eraser(),
)

gen_v = ImageDataGenerator(
)

# %%
base_model = efn.EfficientNetB3(weights=None)
base_model.layers.pop()
base_model.layers.pop()

x = Dense(3, activation='softmax')(base_model.layers[-1].output)

model = Model(inputs=base_model.input, outputs=[x])

#load weights for the second round
#model.load_weights('effnet_ep003-loss5.584-val_loss0.001.h5') 
model.load_weights(r'D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_model\effnet_ep005-loss67.592-val_loss46.489.h5')
# Out:
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\Takatoshi\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
def categorical_focal_loss(y_true, y_pred):
    gamma=2.
    alpha=.25
    y_pred /= K.sum(y_pred, axis=-1, keepdims=True)
    epsilon = K.epsilon()
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    cross_entropy = -y_true * K.log(y_pred)
    loss = alpha * K.pow(1 - y_pred, gamma) * cross_entropy
    return K.mean(loss, axis=1)*10000.0 #to avoid 0.0000





for layer in model.layers: layer.trainable = True
    
model.compile(optimizer=Adadelta(0.2), loss=categorical_focal_loss, metrics=['accuracy'])
train_generator = gen_t.flow_from_directory(path_train, target_size=(300,300), batch_size=batch_size_all)
valid_generator = gen_v.flow_from_directory(path_val,   target_size=(300,300), batch_size=batch_size_all)

#checkpoint      = ModelCheckpoint(r'D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_model\effnet_ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5', monitor='val_loss', save_weights_only=True, save_best_only=False,verbose=1)
checkpoint      = ModelCheckpoint(r'D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_model\effnet_ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}-val_acc{val_acc:.3f}.h5', monitor='val_loss', save_weights_only=True, save_best_only=False,verbose=1)
#reduce_lr       = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, verbose=1, delta=0.03)
reduce_lr       = ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=3, verbose=1, delta=0.03)

model.fit_generator(train_generator,  steps_per_epoch=1000, epochs=epochs_all, 
                    validation_data=valid_generator, validation_steps=np.ceil(imgs_val//batch_size_all),
                    callbacks=[reduce_lr, checkpoint])

# %%
#with this functionality we show boxes with incorect classification. we check them and delete manually boxes
#with incorrect classification
# 誤分類した画像を表示します。

import os
import matplotlib.pyplot as plt
import cv2 as cv
import shutil

target_class = 2 #realize for 0, 1, 2
bad_imgs = 0
dir_imgs_name   = r'D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/'+str(target_class)
move_path       = r'D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\exclusion/'
#dir_imgs_name   = 'C:/Users/Hurtik/python-petr/signate_3rd_ai_edge_competiton/train_imgs_class/val/'+str(target_class)
list_of_imgs = [root+"/"+name
             for root, dirs, files in os.walk(dir_imgs_name)
             for name in files]    

    
for im in range (0, len(list_of_imgs), 1):
    imgcv = cv.cvtColor(cv.imread(list_of_imgs[im]),cv.COLOR_RGB2BGR)
    pred = np.argmax(model.predict(np.expand_dims(imgcv, 0))[0])
    if pred != target_class:
        print(str(im) + ":", list_of_imgs[im])
        shutil.move(list_of_imgs[im], move_path)
        #plt.imshow(imgcv)
        #plt.show()
        bad_imgs += 1
print('bad_imgs: ', bad_imgs)
# Out:
# 39: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_100030.jpg
# 124: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_100118.jpg
# 181: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_
D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_114573.jpg
# 15399: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_11458.jpg
# 15434: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_114610.jpg
# 15465: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_114639.jpg
# 15519: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_114688.jpg
# 15609: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_11478.jpg
# 15616: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_114786.jpg
# 15650: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_114816.jpg
# 15783: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_114936.jpg
# 15804: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_114955.jpg
# 15839: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_114998.jpg
# 15851: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115007.jpg
# 15987: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_11513.jpg
# 16003: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115144.jpg
# 16050: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115187.jpg
# 16066: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115200.jpg
# 16146: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115284.jpg
# 16151: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115289.jpg
# 16187: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115321.jpg
# 16234: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115368.jpg
# 16272: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115405.jpg
# 16303: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115436.jpg
# 16336: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115477.jpg
# 16373: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_11551.jpg
# 16460: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115589.jpg
# 16477: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115603.jpg
# 16518: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115640.jpg
# 16520: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115642.jpg
# 16570: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115688.jpg
# 16593: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115719.jpg
# 16655: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115775.jpg
# 16698: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115813.jpg
# 16708: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115822.jpg
# 16871: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_115980.jpg
# 16905: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_11601.jpg
# 16970: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116069.jpg
# 16976: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116074.jpg
# 17097: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116194.jpg
# 17128: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116221.jpg
# 17160: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116250.jpg
# 17218: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116302.jpg
# 17239: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116321.jpg
# 17287: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116365.jpg
# 17315: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116390.jpg
# 17333: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116406.jpg
# 17422: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116498.jpg
# 17439: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116512.jpg
# 17478: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116548.jpg
# 17508: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116575.jpg
# 17521: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116587.jpg
# 17586: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116645.jpg
# 17641: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116705.jpg
# 17669: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116730.jpg
# 17722: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116779.jpg
# 17764: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116816.jpg
# 17765: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_116817.jpg
# 17998: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117037.jpg
# 18035: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117070.jpg
# 18044: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117079.jpg
# 18059: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117092.jpg
# 18082: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117112.jpg
# 18114: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117152.jpg
# 18133: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_11717.jpg
# 18188: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117219.jpg
# 18214: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117242.jpg
# 18232: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117259.jpg
# 18258: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117282.jpg
# 18272: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117295.jpg
# 18279: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117300.jpg
# 18285: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117306.jpg
# 18297: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117317.jpg
# 18303: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117322.jpg
# 18336: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117352.jpg
# 18393: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117414.jpg
# 18447: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117463.jpg
# 18477: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117490.jpg
# 18478: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117491.jpg
# 18506: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117516.jpg
# 18513: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117522.jpg
# 18565: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_11757.jpg
# 18569: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117573.jpg
# 18579: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117582.jpg
# 18595: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117597.jpg
# 18618: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117628.jpg
# 18622: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117631.jpg
# 18631: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_11764.jpg
# 18654: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117660.jpg
# 18696: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117699.jpg
# 18700: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117701.jpg
# 18736: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117736.jpg
# 18764: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117764.jpg
# 18839: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117838.jpg
# 18916: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117918.jpg
# 18954: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_117952.jpg
# 19065: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_118051.jpg
# 19096: D:\SIGNATE\Signate_3rd_AI_edge_competition\classifier_images\train/2/2_11808.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ea548ab7a65f> in <module>
#      19 for im in range (0, len(list_of_imgs), 1):
#      20     imgcv = cv.cvtColor(cv.imread(list_of_imgs[im]),cv.COLOR_RGB2BGR)
# ---> 21     pred = np.argmax(model.predict(np.expand_dims(imgcv, 0))[0])
#      22     if pred != target_class:
#      23         print(str(im) + ":", list_of_imgs[im])
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1399                                             verbose=verbose,
#    1400                                             steps=steps,
# -> 1401                                             callbacks=callbacks)
#    1402
#    1403     def train_on_batch(self, x, y,
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     330             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     331             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 332             batch_outs = f(ins_batch)
#     333             batch_outs = to_list(batch_outs)
#     334             if batch_index == 0:
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# ~\anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow_core\python\client\session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
