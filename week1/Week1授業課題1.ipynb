# %% [markdown]
# # Week1授業課題1 曽呂利新左衛門問題

# %% [markdown]
# ## 【問題1】100日目の米粒の数

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

RICE= 1
DAYS = 100
rice_count = RICE
rice_ruikei = 0

rice_cnt_list = []     # 当日に貰える米の数
rice_ruikei_list = []  # 類型でもらえる米の数

for i in range(DAYS):
    rice_count *= 2
    rice_cnt_list.append(rice_count)
    rice_ruikei += rice_count
    rice_ruikei_list.append(rice_ruikei)
    

fig, ax1 = plt.subplots(facecolor="w")
ax1.set_title("sorori sinnzaemon")
ax1.set_xlabel("day")
ax1.set_ylabel("rice count", color ='blue')
ax1.grid()
ax1.plot(rice_cnt_list, color ='blue', linestyle='dashed')
ax1.tick_params(axis = 'y', colors ='blue')

ax2 = ax1.twinx()
ax2.set_yscale("log")
ax2.set_ylabel("rice count(log)", color ='red')
ax2.plot(rice_cnt_list,color='red')
ax2.tick_params(axis = 'y', colors ='red')

plt.show()

# %%
# 貰った米の累計グラフを表示
fig, ax1 = plt.subplots(facecolor="w")
ax1.set_title("sorori sinnzaemon")
ax1.set_xlabel("day")
ax1.set_ylabel("rice count total", color ='blue')
ax1.grid()
ax1.plot(rice_ruikei_list, color ='blue', linestyle='dashed')
ax1.tick_params(axis = 'y', colors ='blue')

ax2 = ax1.twinx()
ax2.set_yscale("log")
ax2.set_ylabel("rice count(log)", color ='red')
ax2.plot(rice_ruikei_list,color='red')
ax2.tick_params(axis = 'y', colors ='red')

plt.show()

# %% [markdown]
# # 【問題2】100日目以外の米粒の数

# %%
def compute_sorori_shinzaemon(day=100):
    """
    曽呂利新左衛門の米の逸話を検証する関数。日にちごとの米の粒の数を計算する。

    Parameteres
    --------------
    day: int
        米を貰う日数 (default : 100)

    Returns
    --------------
    list_n_grains : list
        ある日に貰う米の数のリスト（リストの長さはdayに等しくなる）
    list_total_grains : list
        ある日までに累計で貰う米の数のリスト（リストの長さはdayに等しくなる）
    """

    RICE= 1    # 初期値は1粒
    rice_count = RICE
    rice_ruikei = RICE
    rice_cnt_list = [RICE]
    rice_ruikei_list = [RICE]

    for i in range(day):
        rice_count *= 2
        rice_cnt_list.append(rice_count)
        rice_ruikei += rice_count
        rice_ruikei_list.append(rice_ruikei)
    
    '''
    plt.title("thickness of folded paper(linear)")
    plt.xlabel("number of folds")
    plt.ylabel("thickness[m](linear)")
    plt.plot(rice_cnt_list, color="red") 
    plt.plot(rice_ruikei_list, color = "blue") 
    plt.show()
    '''
    return rice_cnt_list, rice_ruikei_list


list_n_grains, list_total_grains = compute_sorori_shinzaemon(day=120)
plt.title("thickness of folded paper(linear)")
plt.xlabel("number of folds")
plt.ylabel("thickness[m](linear)")
plt.plot(rice_cnt_list, color="red") 
plt.plot(rice_ruikei_list, color = "blue") 
plt.show()

# %%
print("list_n_grains =     " + str(list_n_grains))
print("list_total_grains = " + str(list_total_grains))
# Out:
# list_n_grains =     [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912, 1073741824, 2147483648, 4294967296, 8589934592, 17179869184, 34359738368, 68719476736, 137438953472, 274877906944, 549755813888, 1099511627776, 2199023255552, 4398046511104, 8796093022208, 17592186044416, 35184372088832, 70368744177664, 140737488355328, 281474976710656, 562949953421312, 1125899906842624, 2251799813685248, 4503599627370496, 9007199254740992, 18014398509481984, 36028797018963968, 72057594037927936, 144115188075855872, 288230376151711744, 576460752303423488, 1152921504606846976, 2305843009213693952, 4611686018427387904, 9223372036854775808, 18446744073709551616, 36893488147419103232, 73786976294838206464, 147573952589676412928, 295147905179352825856, 590295810358705651712, 1180591620717411303424, 2361183241434822606848, 4722366482869645213696, 94
# ...

# %% [markdown]
# # 【問題3】何人が何日生活できる米か

# %%
def life_sorori_shinzaemon(day, ninzu = 1, need_rice = 0):
    # 指定した日数で貰える米の数を算出
    list_n_grains, list_total_grains = compute_sorori_shinzaemon(day)
    
    # 貰えた米の累計数を人数と1日当たりの必要米粒で割る
    day = list_total_grains[-1] / (ninzu * need_rice)
    
    '''
    day = 0
    while True:
        rice_cnt -= ninzu * need_rice
        day +=1
        if rice_cnt < 0:
            break
        #print(day)
    '''        
    return day

# %%
# 茶碗一杯の米粒を3250粒とする
# 全ての人間が１食１杯だけ食べるとする。(ギャル曽根は対象外！)
# おかわり等は考慮しない
PRIOD = 120    # 4ヶ月(１２０日)
NINZU = 12     # １２人
NEED_RICE = 3250   # 3250粒/１杯
day = life_sorori_shinzaemon(PRIOD, NINZU, NEED_RICE*3)
print("{:.1f}日 生活が可能".format(day))
print("{:.1f}月 生活が可能".format(day/30))
print("{:.1f}年 生活が可能".format(day/30/12))
print("{:.1f}万年 生活が可能".format(day/30/12/10000))
# Out:
# 22721846081793435506583193780224.0日 生活が可能
# 757394869393114573181101801472.0月 生活が可能
# 63116239116092878166394142720.0年 生活が可能
# 6311623911609287464452096.0万年 生活が可能
