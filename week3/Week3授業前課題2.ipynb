# %% [markdown]
# # Week3授業前課題2 住宅情報の分析

# %% [markdown]
# ## 【問題1】データセットの取得

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./HousePrices.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ## 【問題2】データセット自体の調査

# %% [markdown]
# 住宅情報のデータセットとしては、scikit-learnのボストン住宅価格データセット」が有名であるが、
# これは説明変数が13カラム506データなのに対して、今回のエイムズ市の住宅価格データセットは、
# 説明変数が79、データ数1460ある。
#
# ＜目的変数＞
# ・SalePrice：ドルでの販売価格
#
# ＜説明変数＞
# ・MSSubClass: 建物クラス
# ・MSZoning: 一般的なゾーン分類
# ・LotFrontage: ストリートの線形フィート
# ・LotArea: 平方フィート単位のロットサイズ
# ・Street: 道路アクセスタイプ
# ・Alley: 路地アクセスタイプ
# ・LotShape: 一般的形状
# ・LandContour: 平坦性
# ・Utilities: 利用可能なユーティリティタイプ
# ・LotConfig: ロット構成
# ・LandSlope: 土地の斜面
# ・Neighborhood: エイムス市内の制限内の物理的な場所
# ・Condition1: 幹線道路または鉄道に近接している
# ・Condition2: 幹線道路または鉄道に近接している（所要時間）
# ・BldgType: 住居タイプ
# ・HouseStyle: 住居スタイル
# ・OverallQual: 全体的な材料と仕上げ品質
# ・OverallCond: 全体的な状態評価
# ・YearBuilt: 元の建築日
# ・YearRemodAdd: 改造日
# ・RoofStyle: 屋根タイプ
# ・RoofMatl: 屋根材質
# ・Exterior1st: 外装
# ・Exterior2nd: 外装 (複数素材)
# ・MasVnrType: 石積みべニアタイプ
# ・MasVnrArea: 平方フィート当たりの石積みべニア
# ・ExterQual: 外装素材品質
# ・ExterCond: 外装素材の現状
# ・Foundation: 施工タイプ
# ・BsmtQual: 地下室の高さ
# ・BsmtCond: 地下室の一般的な状態
# ・BsmtExposure: 地下壁のウォークアウトもしくは庭園レベル
# ・BsmtFinType1: 地下室の仕上がり面積の品質
# ・BsmtFinSF1: タイプ１の仕上げ済み平方フィート
# ・BsmtFinType2: 二つ目の仕上げ品質 (存在する場合)
# ・BsmtFinSF2: タイプ２の仕上げ済み平方フィート
# ・BsmtUnfSF: 地下室の未完成領域の平方フィート
# ・TotalBsmtSF: 地下室の合計平方フィート
# ・Heating: 暖房の種類
# ・HeatingQC: 暖房の品質と状態
# ・CentralAir: 空調の集中管理
# ・Electrical: 電気システム
# ・1stFlrSF: １階の平方フィート
# ・2ndFlrSF: ２階の平方フィート
# ・LowQualFinSF: 低品質の完成済み平方フィート (全階)
# ・GrLivArea: (地上)グレード以上のリビングの平方フィート
# ・BsmtFullBath: 地下のフルバス
# ・BsmtHalfBath: 地下のハーフバス
# ・FullBath: グレードを超えるフルバス
# ・HalfBath: グレードを超えるハーフバス
# ・Bedroom: 地下より上のベッドルームの数
# ・Kitchen: キッチンの数
# ・KitchenQual: キッチン品質
# ・TotRmsAbvGrd: 全ての部屋のグレード (バスルームは含まない)
# ・Functional: ホーム機能の評価
# ・Fireplaces: 暖炉の数
# ・FireplaceQu: 暖炉の品質
# ・GarageType: ガレージの場所
# ・GarageYrBlt: ガレージが作られた年
# ・GarageFinish: ガレージの内部仕上げ
# ・GarageCars: 車の容量に対するガレージサイズ
# ・GarageArea: 平方フィート当たりのガレージサイズ
# ・GarageQual: Gガレージ品質
# ・GarageCond: ガレージ状態
# ・PavedDrive: 舗装された道路
# ・WoodDeckSF: ウッドデッキの面積（平方フィート）
# ・OpenPorchSF: オープンポーチエリアの平方フィート
# ・EnclosedPorch: クローズドポーチエリアの平方フィート
# ・3SsnPorch: スリーシーズンポーチエリアの平方フィート
# ・ScreenPorch: スクリーンポーチエリアの平方フィート
# ・PoolArea: プールの平方フィート
# ・PoolQC: プール品質
# ・Fence: フェンス品質
# ・MiscFeature: 他のカテゴリに含まれないその他機能
# ・MiscVal: その他機能の価格
# ・MoSold:販売月
# ・YrSold: 販売年
# ・SaleType: 販売タイプ
# ・SaleCondition: 販売状態

# %% [markdown]
# ## 【問題3】データの確認

# %% [markdown]
# 今回の目的変数はどの列か確認する。
# 　⇒今回の目的変数は最終列の"SalePrice"

# %%
# 各特徴量がどういったものかを見る。（数値データか文字データなど）
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# 特徴量の平均値と標準偏差、四分位数を一度に表示させる。
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# ## 【問題4】欠損値への対応

# %%
import missingno as msno

# 欠損値をMatrix表示
msno.matrix(df)

# %%
# カラムidからHeatingまでを棒グラフ化
msno.bar(df.iloc[:,0:40])

# %%
# カラムHeatingQCからSalesPraceまでを棒グラフ化
msno.bar(df.iloc[:,40:])

# %% [markdown]
# ### 欠損値が何パーセント含まれるかを確認する。
#
# | column        | missing_count | Total | missing_ratio |
# |---------------|--------------:|------:|---------------|
# | id            |             0 |  1460 | 0             |
# | MSSubClass    |             0 |  1460 | 0             |
# | MSZoning      |             0 |  1460 | 0             |
# | LotFrontage   |           259 |  1201 | 0.17739726    |
# | LotArea       |             0 |  1460 | 0             |
# | Street        |             0 |  1460 | 0             |
# | Alley         |          1369 |    91 | 0.937671233   |
# | LotShape      |             0 |  1460 | 0             |
# | LandContour   |             0 |  1460 | 0             |
# | Utilities     |             0 |  1460 | 0             |
# | LotConfig     |             0 |  1460 | 0             |
# | LandSlope     |             0 |  1460 | 0             |
# | Neighborhood  |             0 |  1460 | 0             |
# | Condition1    |             0 |  1460 | 0             |
# | Condition2    |             0 |  1460 | 0             |
# | BldgType      |             0 |  1460 | 0             |
# | HouseStyle    |             0 |  1460 | 0             |
# | OverallQual   |             0 |  1460 | 0             |
# | OverallCond   |             0 |  1460 | 0             |
# | YearBuilt     |             0 |  1460 | 0             |
# | YearRemodAdd  |             0 |  1460 | 0             |
# | RoofStyle     |             0 |  1460 | 0             |
# | RoofMatl      |             0 |  1460 | 0             |
# | Exterior1st   |             0 |  1460 | 0             |
# | Exterior2nd   |             0 |  1460 | 0             |
# | MasVnrType    |             8 |  1452 | 0.005479452   |
# | MasVnrArea    |             8 |  1452 | 0.005479452   |
# | ExterQual     |             0 |  1460 | 0             |
# | ExterCond     |             0 |  1460 | 0             |
# | Foundation    |             0 |  1460 | 0             |
# | BsmtQual      |            37 |  1423 | 0.025342466   |
# | BsmtCond      |            37 |  1423 | 0.025342466   |
# | BsmtExposure  |            38 |  1422 | 0.026027397   |
# | BsmtFinType1  |            37 |  1423 | 0.025342466   |
# | BsmtFinSF1    |             0 |  1460 | 0             |
# | BsmtFinType2  |            38 |  1422 | 0.026027397   |
# | BsmtFinSF2    |             0 |  1460 | 0             |
# | BsmtUnfSF     |             0 |  1460 | 0             |
# | TotalBsmtSF   |             0 |  1460 | 0             |
# | Heating       |             0 |  1460 | 0             |
# | HeatingQC     |             0 |  1460 | 0             |
# | CentralAir    |             0 |  1460 | 0             |
# | Electrical    |             1 |  1459 | 0.000684932   |
# | 1stFlrSF      |             0 |  1460 | 0             |
# | 2ndFlrSF      |             0 |  1460 | 0             |
# | LowQualFinSF  |             0 |  1460 | 0             |
# | GrLivArea     |             0 |  1460 | 0             |
# | BsmtFullBath  |             0 |  1460 | 0             |
# | BsmtHalfBath  |             0 |  1460 | 0             |
# | FullBath      |             0 |  1460 | 0             |
# | HalfBath      |             0 |  1460 | 0             |
# | Bedroom       |             0 |  1460 | 0             |
# | Kitchen       |             0 |  1460 | 0             |
# | KitchenQual   |             0 |  1460 | 0             |
# | TotRmsAbvGrd  |             0 |  1460 | 0             |
# | Functional    |             0 |  1460 | 0             |
# | Fireplaces    |             0 |  1460 | 0             |
# | FireplaceQu   |           690 |   770 | 0.47260274    |
# | GarageType    |            81 |  1379 | 0.055479452   |
# | GarageYrBlt   |            81 |  1379 | 0.055479452   |
# | GarageFinish  |            81 |  1379 | 0.055479452   |
# | GarageCars    |             0 |  1460 | 0             |
# | GarageArea    |             0 |  1460 | 0             |
# | GarageQual    |            81 |  1379 | 0.055479452   |
# | GarageCond    |            81 |  1379 | 0.055479452   |
# | PavedDrive    |             0 |  1460 | 0             |
# | WoodDeckSF    |             0 |  1460 | 0             |
# | OpenPorchSF   |             0 |  1460 | 0             |
# | EnclosedPorch |             0 |  1460 | 0             |
# | 3SsnPorch     |             0 |  1460 | 0             |
# | ScreenPorch   |             0 |  1460 | 0             |
# | PoolArea      |             0 |  1460 | 0             |
# | PoolQC        |          1453 |     7 | 0.995205479   |
# | Fence         |          1179 |   281 | 0.807534247   |
# | MiscFeature   |          1406 |    54 | 0.963013699   |
# | MiscVal       |             0 |  1460 | 0             |
# | MoSold        |             0 |  1460 | 0             |
# | YrSold        |             0 |  1460 | 0             |
# | SaleType      |             0 |  1460 | 0             |
# | SaleCondition |             0 |  1460 | 0             |

# %%
# 5つ以上欠損値がある特徴量（列）は削除する。

# 以下の１８カラムを削除する。
# LotFrontage
# Alley
# MasVnrType
# MasVnrArea
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageQual
# GarageCond
# PoolQC
# Fence
# MiscFeature


df_House = df.drop(['LotFrontage', 'Alley', 'MasVnrType','MasVnrArea' ,'BsmtQual' ,'BsmtCond' , 
                          'BsmtExposure','BsmtFinType1' ,'BsmtFinType2' ,'FireplaceQu' ,'GarageType' ,'GarageYrBlt' , 
                          'GarageFinish','GarageQual' ,'GarageCond' ,'PoolQC' ,'Fence' ,'MiscFeature'], axis=1)

# カラムElectricalの欠損数が１なのでdropnaは使えない
# df_House = df.dropna(axis=1)

df_House.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 63 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
# 欠損値があるサンプル（行）は削除する。
# カラムElectricalに欠損値を含む１データが削除される。
df_House = df_House.dropna()

# %%
# 欠損値の削除確認　３２列まで
msno.bar(df_House.iloc[:,0:32])

# %%
# 欠損値の削除確認　３２列以降
msno.bar(df_House.iloc[:,32:])

# %% [markdown]
# ## 【問題5】用語の調査

# %% [markdown]
# ### ＜尖度＞

# %% [markdown]
# 尖度(せんど):確率変数の確率密度関数や頻度分布の鋭さを表す数字である。
#              正規分布と比べて、尖度が大きければ鋭いピークと長く太い裾を持った分布を持ち、
#              尖度が小さければより丸みがかったピークと短く細い尾を持った分布であるという事が判断できる。

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,12))

img_sendo = mpimg.imread("./尖度.png")
imgplot = plt.imshow(img_sendo)

# %% [markdown]
# ### ＜歪度＞

# %% [markdown]
# 歪度(わいど):平均まわりの三次モーメントを標準偏差で正規化したもので，分布の歪み具合（どれくらい非対称なのか）を表す。

# %%
plt.figure(figsize=(8,8))

img_waido = mpimg.imread("./歪度.png")
imgplot = plt.imshow(img_waido)

# %% [markdown]
# ## 【問題6】分布の確認

# %%
import seaborn as sns
import scipy
import numpy as np
sns.distplot(df_House.iloc[:,-1:], bins=50)


print("尖度：", scipy.stats.kurtosis(df_House.iloc[:,-1:]))
print("歪度：", scipy.stats.skew(df_House.iloc[:,-1:]))
print("平均：", np.mean((df_House.iloc[:,-1:])))
# Out:
# 尖度： [6.50279911]
# 歪度： [1.88000761]
# 平均： SalePrice    180930.394791
# dtype: float64

# %%
df_log = df_House.iloc[:,-1:].apply(np.log)
df_log
sns.distplot(df_log.iloc[:,-1:], bins=50)
print("歪度", scipy.stats.skew(df_log))
print("尖度", scipy.stats.kurtosis(df_log))
# Out:
# 歪度 [0.121193]
# 尖度 [0.80005557]

# %%
# 平均値
np.mean(df_log)
# Out:
# SalePrice    12.024048
# dtype: float64

# %% [markdown]
# 正規分布では、尖度・歪度 共に0となる。
# 対数変換前の目的変数は尖度・歪度 共に高い値をしめしているが、
# 対数変換を行う事によって尖度・歪度 共に0に近づき、正規分布に近い値となる。

# %% [markdown]
# ## 【問題7】相関係数の確認

# %% [markdown]
# ### ＜相関係数行列のヒートマップを作り、相関係数の高い関係を見つける。＞

# %%
# 相関係数行列のヒートマップを作り、相関係数の高い関係を見つける。
import seaborn as sns

df_corr = df_House.corr()
fig, ax = plt.subplots(figsize=(13, 10)) 
sns.heatmap(df_corr, vmax=1, vmin=-1, center=0)
#sns.heatmap(df_corr, vmax=1, vmin=0.38, center=0)

# %% [markdown]
# ### ＜目的変数との相関の高い特徴量10個を選び、これらだけの相関係数行列ヒートマップを作る。＞

# %%
# 10項目を抽出
df_piclup =df_House[["OverallQual","YearBuilt","YearRemodAdd","TotalBsmtSF","1stFlrSF",
          "GrLivArea","FullBath","TotRmsAbvGrd","GarageCars","GarageArea","SalePrice"]]
df_piclup
# Out:
#       OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0               7       2003          2003          856       856       1710
# 1               6       1976          1976         1262      1262       1262
# 2               7       2001          2002          920       920       1786
# 3               7       1915          1970          756       961       1717
# 4               8       2000          2000         1145      1145       2198
# ...           ...        ...           ...          ...       ...        ...
# 1455            6       1999          2000          953       953       1647
# 1456            6       1978          1988         1542      2073       2073
# 1457            7       1941          2006         1152      1188       2340
# 1458            5       1950          1996         1078      1078       1078
# 1459            5       1965          1965         1256      1256       1256
#
# ...

# %%
df_piclup_corr = df_piclup.corr()
fig, ax = plt.subplots(figsize=(13, 10)) 
sns.heatmap(df_piclup_corr, vmax=1, vmin=-1, center=0, annot=True)

# %% [markdown]
# ### ＜選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる。＞

# %% [markdown]
# 選んだ10個の特徴量が何か表しているかをKaggleのDataDescriptionの記述を参考に日本語でまとめる。
#
# ①OverallQual: 全体的な材料と仕上げ品質
# ②YearBuilt: 元の建築日
# ③YearRemodAdd: 改造日
# ④TotalBsmtSF: 地下室の合計平方フィート
# ⑤1stFlrSF: １階の平方フィート
# ⑥GrLivArea: (地上)グレード以上のリビングの平方フィート
# ⑦FullBath: グレードを超えるフルバス
# ⑧TotRmsAbvGrd: 全ての部屋のグレード (バスルームは含まない)
# ⑨GarageCars: 車の容量に対するガレージサイズ
# ⑩GarageArea 平方フィート当たりのガレージサイズ

# %% [markdown]
# ### ＜選んだ10個の特徴量の中でお互いの相関係数が高い組み合わせを3つ探し出す。＞
#
# ヒートマップより相関係数が高い組合せは
# 〇TotalBsmtSFと1stFlrSF
# 〇GrLivAreaとTotRmsAbvGrd
# 〇GarageCarsとGarageArea
