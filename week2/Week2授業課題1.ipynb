# %% [markdown]
# # Week2授業課題1 二次元配列と勾配問題

# %% [markdown]
# ## 1.このテキストについて
# <u>テキストの目的</u>
# ・数式演算ライブラリのNumPyに慣れる
# ・勾配を求めてみる
#
# <u>どのように学ぶか</u>
# NumPyについていろいろな機能に触れつつ、勾配について学んでいきます。

# %% [markdown]
# ## 2.二次元配列と勾配問題
# 機械学習においては関数の最小値を見つけることが重要になってきます。そのために使われるのが勾配降下法です。
#
#
# この課題では勾配降下法を理解する準備として、NumPyを用いて関数の勾配を考えていきます。

# %% [markdown]
# ## 【問題1】1次関数
# $x$ が-50から50の範囲で次の式を考えます。
#
# $
# y = \frac{1}{2}x + 1
# $
#
# -50から50まで0.1間隔のxを表すndarrayと、各要素に対するyを表すndarrayを作成してください。

# %%
import numpy as np

# ndarrayの初期化
x = np.arange(-50, 50.1 ,0.1)

# 2次元配列に変換
x = x.reshape(1001,-1)
print("type(x):{}".format(type(x)))

y = (1/2)*x + 1
      
print("type(y):{}".format(type(y)))

print("x.shape:{}".format(x.shape))
print("y.shape:{}".format(y.shape))
# Out:
# type(x):<class 'numpy.ndarray'>
# type(y):<class 'numpy.ndarray'>
# x.shape:(1001, 1)
# y.shape:(1001, 1)

# %% [markdown]
# ## 【問題2】配列の結合
# 問題1で作成したndarrayを結合し、(1001, 2)の形の配列にしてください。0列目にx、1列目にyが来るようにします。

# %%
# concatenateで結合
ndarray_concat = np.concatenate([x, y], axis = 1)

print("ndarray_concat.shape={}".format(ndarray_concat.shape))
print("ndarray_concat =\n{}".format(ndarray_concat))
# Out:
# ndarray_concat.shape=(1001, 2)
# ndarray_concat =
# [[-50.   -24.  ]
#  [-49.9  -23.95]
#  [-49.8  -23.9 ]
#  ...
#  [ 49.8   25.9 ]
#  [ 49.9   25.95]
#  [ 50.    26.  ]]

# %% [markdown]
# ## 【問題3】勾配を求める
# 各x座標における勾配を求めます。ここで勾配はyの変化量をxの変化量で割ることで計算します。
#
# <img src="https://t.gyazo.com/teams/diveintocode/7fd04c4808b8a0150a49c908e21f3cd2.png">
#
# 各変化量は以下の図のように隣同士の要素の差から近似的に求めます。
#
# <img src="https://t.gyazo.com/teams/diveintocode/398d8c5b4b1bd4151dea6488059226a1.png">
#
# 《注意》
#
# ・厳密に各点における勾配を求めるには極限（微分）を利用する必要があります
# ・勾配はx座標の間隔を使うので、xの要素数に対して一つ少なくなります

# %%
d_x = x[1:]-x[:-1]
d_y = y[1:]-y[:-1]

# 勾配計算
grad = d_y/d_x
print("type(d_a)={}".format(type(grad)))
print("d_a.shape={}".format(grad.shape))
print("d_a=\n{}".format(grad))
# Out:
# type(d_a)=<class 'numpy.ndarray'>
# d_a.shape=(1000, 1)
# d_a=
# [[0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
#  [0.5]
# ...

# %% [markdown]
# ##  【問題4】グラフを描く
# 1次関数のグラフをMatplotlibを用いて描いてください。また、それとは別に横軸をx、縦軸を勾配としたグラフも描いてください。
#
#
# [matplotlib.pyplot.plot — Matplotlib 3.1.0 documentation](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Linear")
plt.show()

# %%
import copy
# xをコピー
grad_x = copy.deepcopy(x).reshape(x.shape[0], -1)

# gradの要素数が1001なので末尾を削除
grad_x = np.delete(grad_x, grad_x.shape[0]-1, 0)
plt.plot(grad_x,grad)
plt.xlabel("x")
plt.ylabel("Grad")
plt.title("Grad")
plt.show()

# %% [markdown]
# ## 【問題5】Pythonの関数化
# 問題1から問題3までの範囲をまとめて行うPythonの関数を雛形を参考に作成してください。
#
#
# そして、以下の3式の勾配を0.1間隔で求めてndarrayで出力してください。
#
# $
# y = x^{2} \quad (-50\leq x \leq 50)\\
# y = 2x^{2}+2^{x} \quad (-50\leq x \leq 50)\\
# y = sin(x^{\frac{1}{2}}) \quad (0\leq x \leq 50)
# $
#
# また、問題4と同様にグラフを描いてください。
#
#
# ndarrayに対して三角関数のsinの計算を行うには np.sin()を用います。
#
#
# [numpy.sin — NumPy v1.16 Manual](https://docs.scipy.org/doc/numpy/reference/generated/numpy.sin.html#numpy.sin)

# %%
def compute_gradient(function, x_range=(-50, 50.1, 0.1)):
    """
    変化量を使い勾配を計算する。

    Parameters
    ----------------
    function : function
    求めたい関数、xのndarrayを入れるとyのndarrayを返すもの。
    x_range : tuple
    np.arange()の引数と同じ方法で範囲を指定する。

    Returns
    ----------------
    array_xy : ndarray, shape(n, 2)
    xとyを結合したもの。nはx_rangeに依存する。
    gradient : ndarray, shape(n-1,)
    関数の勾配。差をとるため要素は1つ減る
    """

    x = np.arange(x_range[0],x_range[1],x_range[2])
    y = function(x)
    
    x = x.reshape(x.shape[0], -1)
    y = y.reshape(y.shape[0], -1)

    d_x = x[1:]-x[:-1]
    d_y = y[1:]-y[:-1]

    # 勾配計算
    gradient = d_y/d_x
    
    # concatenateで結合
    array_xy = np.concatenate([x, y], axis = 1)
    
    return array_xy, gradient

def function1(array_x):
    array_y = (1/2)*array_x + 1
    return array_y


print("＜function1＞")
array_xy1, gradient1 = compute_gradient(function1)

plt.plot(array_xy1[:,0],array_xy1[:,1])
plt.xlabel("x")
plt.ylabel("y")
plt.title("function1")
plt.show()
# Out:
# ＜function1＞

# %%
def function2(array_x):
    array_y = array_x**2
    return array_y

print("＜function2＞")
array_xy2, gradient2 = compute_gradient(function2)

plt.plot(array_xy2[:,0],array_xy2[:,1])
plt.xlabel("x")
plt.ylabel("y")
plt.title("function2")
plt.show()
# Out:
# ＜function2＞

# %%
def function3(array_x):
    array_y = 2 * array_x**2 + 2**array_x
    return array_y

print("＜function3＞")
array_xy3, gradient3 = compute_gradient(function3)

plt.plot(array_xy3[:,0],array_xy3[:,1])
plt.xlabel("x")
plt.ylabel("y")
plt.title("function3")
plt.show()
# Out:
# ＜function3＞

# %%
def function4(array_x):
    array_y = np.sin(array_x**(1/2))
    return array_y

print("＜function4＞")
array_xy4, gradient4 = compute_gradient(function4, x_range=(0, 50.1, 0.1))

plt.plot(array_xy4[:,0],array_xy4[:,1])
plt.xlabel("x")
plt.ylabel("y")
plt.title("function4")
plt.show()
# Out:
# ＜function4＞

# %% [markdown]
# ## 【問題6】最小値を求める
# 問題5で扱った関数のyの最小値を求めます。xの範囲も問題5と同様とします。
#
#
# 今回は勾配降下法ではなく、ndarrayのminメソッド、argminメソッドを用いてください。minメソッドは最小値を、argminメソッドは最小値のインデックスを取得することができます。
#
#
# また、最小のyをとる前後の勾配を表示してください。
#
#
# [numpy.ndarray.min — NumPy v1.16 Manual](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.min.html)
#
#
# [numpy.ndarray.argmin — NumPy v1.16 Manual](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.argmin.html)

# %%
array_xy1, gradient1 = compute_gradient(function1)
print("function1のyの最小値：{}".format(np.min(array_xy1[:,1])))
# Out:
# function1のyの最小値：-24.0

# %%
array_xy2, gradient2 = compute_gradient(function2)
print("function2のyの最小値：{}".format(np.min(array_xy2[:,1])))
# Out:
# function2のyの最小値：5.048709793414476e-25

# %%
array_xy3, gradient3 = compute_gradient(function3)
print("function3のyの最小値：{}".format(np.min(array_xy3[:,1])))
# Out:
# function3のyの最小値：0.9505505632959851

# %%
array_xy4, gradient4 = compute_gradient(function4, x_range=(0, 50.1, 0.1))
print("function4のyの最小値：{}".format(np.min(array_xy4[:,1])))
# Out:
# function4のyの最小値：-0.9999997540298113
